# %%
ice_cream_rating = 10
sleeping_rating = 9

# %%
first_name = input("What is your first name? ")
last_name = input("What is your last name? ")
my_name = first_name + " " + last_name
# Out:
# What is your first name?  Elli
# What is your last name?  Vikstedt

# %%
happiness_rating = (ice_cream_rating + sleeping_rating) / 2

# %%
print(type(ice_cream_rating), type(first_name), type(happiness_rating))
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %%
#Did all of the data types make sense? Were there any data types that were different than you expected? 

#These data types made sense since ice_cream_rating was entered in integers, input-function produces string data and happiness rating for these numbers cannot be in integers so float type is used.

# %%
My name is Dave and I give eating ice cream a score of 9 out of 10!
I am Dave Whipp and my sleeping enjoyment rating is 8 / 10!
Based on the factors above, my happiness rating is 8.5 out of 10, or 85.0 %!

print("My name is" , first_name, "and i give eating ice cream a score of", ice_cream_rating, "out of 10!")
print("I am", my_name, "and my sleeping enjoyment rating is", sleeping_rating, "/ 10!")
print("Based on the factors above, my happiness rating is", happiness_rating, "out of 10,", "or", happiness_rating * 10, "%!")
